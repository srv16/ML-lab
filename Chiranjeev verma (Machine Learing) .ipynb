# %%
import PyPDF2 as pdf
import os
import re
for file in os.listdir('.'):
    if file.endswith('.pdf'):
        _file=pdf.PdfFileReader(file)
        text=_file.getPage(0).extractText()
        name=text[text.index('Name')+2:text.index('Father Name'):]
        fname=text[text.index('Father Name'):]
        mname=text[text.index('Mother Name'):]
        patterns=re.compile('[A-Z]{4}-[a-z]{2}-[1-9]{2}')            
        save_file=open('srv.csv','a')
        save_file.close()
        print(fname)
        print(mname)
# Out:
# Father NameSANJEEV KUMAR VERMAMother NameANJALI VERMADate of Birth2001-07-16GenderMALECategoryOBCAddressH NO 34 PUSHPANJALI ECO CITY,NAGLA KALI AGRACityAGRAPincode282009StateUTTAR PRADESHPhone8077966386AddressH NO 34 PUSHPANJALI ECO CITY,NAGLA KALI AGRACityAGRAPincode282009StateUTTAR PRADESHPhone8077966386S.No.Course TypeCourse CodeCourse NameCredits1Major CourseITV301PYTHON BASED DATA MNGT. & VISUALIZ.4.002Major CourseITV302PRINCIPLES OF INTERNET OF THINGS4.003Major CourseITV303COMPUTER NETWORKS4.004Major CourseITV304MICROCONTROLLERS3.005Major CourseITV305DATA MNGT.& VISUALIZ. LAB IN PYTHON3.006Major CourseITV306COMPUTER NETWORKS LAB3.007Major CourseITV307MICROCONTROLLER LAB3.008Major CourseITV308PROJECT II3.009Major CourseITV309SOFT SKILLS&PERSONALITY DEVELOPMENT2.0010CoreGKC391SC.METH. G.K. & CURRENT AFFAIRS III1.0011CoreRDC192SOCIAL SERVICE1.00TOTAL COURSES : 11TOTAL THEORY CREDITS : 13.00TOTAL PRACTICAL CREDITS : 18.00TOTAL REGISTERED CREDITS : 31.00Date Of Registration20-07-201
# ...
